# %% [markdown]
# # IMPORTING REQUIRED LIBRARIES

# %%
import numpy as np 
import pandas as pd 
import os

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # READING DATA

# %%
df1=pd.read_csv("prevalence-by-mental-and-substance-use-disorder.csv")
df2=pd.read_csv("mental-and-substance-use-as-share-of-disease.csv")

# %%
df1.head()
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1990
# 1  Afghanistan  AFG  1991
# 2  Afghanistan  AFG  1992
# 3  Afghanistan  AFG  1993
# 4  Afghanistan  AFG  1994
#
#    Prevalence - Schizophrenia - Sex: Both - Age: Age-standardized (Percent)  \
# 0                                           0.228979
# 1                                           0.228120
# 2                                           0.227328
# 3                                           0.226468
# 4                                           0.225567
#
#    Prevalence - Bipolar disorder - Sex: Both - Age: Age-standardized (Percent)  \
# 0                                           0.721207
# 1                                           0.719952
# 2                                           0.718418
# 3                                           0.717452
# 4                                           0.717012
#
#    Prevalence - Eating disorders - Sex: Both - Age: Age-standardized (Percent)  \
# ...

# %%
df2.head()
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1990
# 1  Afghanistan  AFG  1991
# 2  Afghanistan  AFG  1992
# 3  Afghanistan  AFG  1993
# 4  Afghanistan  AFG  1994
#
#    DALYs (Disability-Adjusted Life Years) - Mental disorders - Sex: Both - Age: All Ages (Percent)
# 0                                           1.696670
# 1                                           1.734281
# 2                                           1.791189
# 3                                           1.776779
# 4                                           1.712986

# %% [markdown]
# # MERGING TWO DATASETS

# %%
data = pd.merge(df1, df2)
data.head()
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1990
# 1  Afghanistan  AFG  1991
# 2  Afghanistan  AFG  1992
# 3  Afghanistan  AFG  1993
# 4  Afghanistan  AFG  1994
#
#    Prevalence - Schizophrenia - Sex: Both - Age: Age-standardized (Percent)  \
# 0                                           0.228979
# 1                                           0.228120
# 2                                           0.227328
# 3                                           0.226468
# 4                                           0.225567
#
#    Prevalence - Bipolar disorder - Sex: Both - Age: Age-standardized (Percent)  \
# 0                                           0.721207
# 1                                           0.719952
# 2                                           0.718418
# 3                                           0.717452
# 4                                           0.717012
#
#    Prevalence - Eating disorders - Sex: Both - Age: Age-standardized (Percent)  \
# ...

# %%
data.set_axis(['Country','code','Year','Schizophrenia', 'Bipolar_disorder', 'Eating_disorder','Anxiety','drug_usage','depression','alcohol','mental_disorder'], axis='columns', inplace=True)

# %% [markdown]
# # DATA CLEANING

# %%
from pandas_profiling import ProfileReport
prof = ProfileReport(data)
prof.to_file(output_file='MentalFitnessReport.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
data.isnull().sum()
# Out:
# Country               0
# code                690
# Year                  0
# Schizophrenia         0
# Bipolar_disorder      0
# Eating_disorder       0
# Anxiety               0
# drug_usage            0
# depression            0
# alcohol               0
# mental_disorder       0
# dtype: int64

# %%
data.drop('code',axis=1,inplace=True)

# %%
data.head()
# Out:
#        Country  Year  Schizophrenia  Bipolar_disorder  Eating_disorder  \
# 0  Afghanistan  1990       0.228979          0.721207         0.131001
# 1  Afghanistan  1991       0.228120          0.719952         0.126395
# 2  Afghanistan  1992       0.227328          0.718418         0.121832
# 3  Afghanistan  1993       0.226468          0.717452         0.117942
# 4  Afghanistan  1994       0.225567          0.717012         0.114547
#
#     Anxiety  drug_usage  depression   alcohol  mental_disorder
# 0  4.835127    0.454202    5.125291  0.444036         1.696670
# 1  4.821765    0.447112    5.116306  0.444250         1.734281
# 2  4.801434    0.441190    5.106558  0.445501         1.791189
# 3  4.789363    0.435581    5.100328  0.445958         1.776779
# 4  4.784923    0.431822    5.099424  0.445779         1.712986

# %%
data.skew()
# Out:
# Year                0.000000
# Schizophrenia       0.709851
# Bipolar_disorder    0.296765
# Eating_disorder     1.712307
# Anxiety             1.082386
# drug_usage          2.078850
# depression          0.557049
# alcohol             0.670753
# mental_disorder     0.403478
# dtype: float64

# %%
data.size,data.shape
# Out:
# (68400, (6840, 10))

# %%
data.set_axis(['Country','Year','Schizophrenia', 'Bipolar_disorder', 'Eating_disorder','Anxiety','drug_usage','depression','alcohol','mental_disorder'], axis='columns', inplace=True)

# %%
data.head()
# Out:
#        Country  Year  Schizophrenia  Bipolar_disorder  Eating_disorder  \
# 0  Afghanistan  1990       0.228979          0.721207         0.131001
# 1  Afghanistan  1991       0.228120          0.719952         0.126395
# 2  Afghanistan  1992       0.227328          0.718418         0.121832
# 3  Afghanistan  1993       0.226468          0.717452         0.117942
# 4  Afghanistan  1994       0.225567          0.717012         0.114547
#
#     Anxiety  drug_usage  depression   alcohol  mental_disorder
# 0  4.835127    0.454202    5.125291  0.444036         1.696670
# 1  4.821765    0.447112    5.116306  0.444250         1.734281
# 2  4.801434    0.441190    5.106558  0.445501         1.791189
# 3  4.789363    0.435581    5.100328  0.445958         1.776779
# 4  4.784923    0.431822    5.099424  0.445779         1.712986

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %%
sns.lineplot(data['Year'],data['mental_disorder'])
# Out:
# <AxesSubplot:xlabel='Year', ylabel='mental_disorder'>

# %%
sns.scatterplot(data['Year'], data['mental_disorder'])
# Out:
# <AxesSubplot:xlabel='Year', ylabel='mental_disorder'>

# %%
plt.figure(figsize=(12,6))
sns.heatmap(data.corr(),annot=True)
plt.plot()
# Out:
# []

# %%
sns.jointplot('Schizophrenia','mental_disorder',data,kind='reg',color='green')
plt.show()

# %%
sns.jointplot('Bipolar_disorder','mental_disorder',data,kind='reg',color='blue')
plt.show()

# %%
sns.pairplot(data,corner=True)
plt.show()

# %%
mean = data['mental_disorder'].mean()
mean
# Out:
# 4.818061811758911

# %%
fig = px.pie(data, values='mental_disorder', names='Year')
fig.show()
# Out:
# <div>                            <div id="4bba56f2-0aa0-4cc8-ac7e-3ce87a718426" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4bba56f2-0aa0-4cc8-ac7e-3ce87a718426")) {                    Plotly.newPlot(                        "4bba56f2-0aa0-4cc8-ac7e-3ce87a718426",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Year=%{label}<br>mental_disorder=%{value}<extra></extra>","labels":[1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,1990,1991,1992,1993,1994,1995,1996,1997,19
# ...

# %%
fig=px.bar(data.head(10),x='Year',y='mental_disorder',color='Year',template='ggplot2')
fig.show()
# Out:
# <div>                            <div id="2a60f144-f403-4272-80d1-da1ab239887e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2a60f144-f403-4272-80d1-da1ab239887e")) {                    Plotly.newPlot(                        "2a60f144-f403-4272-80d1-da1ab239887e",                        [{"alignmentgroup":"True","hovertemplate":"Year=%{marker.color}<br>mental_disorder=%{y}<extra></extra>","legendgroup":"","marker":{"color":[1990,1991,1992,1993,1994,1995,1996,1997,1998,1999],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[1990,1991,1992,1993,1994,1995,1996,1997,1998,1999],"xaxis":"x","y":[1.696670483,1.734281366,1.79118945,1.776779315,1.712985931,1.738271645
# ...

# %% [markdown]
# # YEARWISE VARIATIONS IN MENTAL FITNESS OF DIFFERENT COUNTRIES

# %%
fig = px.line(data, x="Year", y="mental_disorder", color='Country',markers=True,color_discrete_sequence=['red','blue'],template='plotly_dark')
fig.show()
# Out:
# <div>                            <div id="4f257e2b-7c4b-4f71-9112-a20a4a784b10" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4f257e2b-7c4b-4f71-9112-a20a4a784b10")) {                    Plotly.newPlot(                        "4f257e2b-7c4b-4f71-9112-a20a4a784b10",                        [{"hovertemplate":"Country=Afghanistan<br>Year=%{x}<br>mental_disorder=%{y}<extra></extra>","legendgroup":"Afghanistan","line":{"color":"red","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Afghanistan","showlegend":true,"x":[1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019],"xaxis":"x","y":[1.696670483,1.734281366,1.79118945,1.776779315
# ...

# %%
df = data.copy()

# %%
df.head()
# Out:
#        Country  Year  Schizophrenia  Bipolar_disorder  Eating_disorder  \
# 0  Afghanistan  1990       0.228979          0.721207         0.131001
# 1  Afghanistan  1991       0.228120          0.719952         0.126395
# 2  Afghanistan  1992       0.227328          0.718418         0.121832
# 3  Afghanistan  1993       0.226468          0.717452         0.117942
# 4  Afghanistan  1994       0.225567          0.717012         0.114547
#
#     Anxiety  drug_usage  depression   alcohol  mental_disorder
# 0  4.835127    0.454202    5.125291  0.444036         1.696670
# 1  4.821765    0.447112    5.116306  0.444250         1.734281
# 2  4.801434    0.441190    5.106558  0.445501         1.791189
# 3  4.789363    0.435581    5.100328  0.445958         1.776779
# 4  4.784923    0.431822    5.099424  0.445779         1.712986

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6840 entries, 0 to 6839
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Country           6840 non-null   object
#  1   Year              6840 non-null   int64
#  2   Schizophrenia     6840 non-null   float64
#  3   Bipolar_disorder  6840 non-null   float64
#  4   Eating_disorder   6840 non-null   float64
#  5   Anxiety           6840 non-null   float64
#  6   drug_usage        6840 non-null   float64
#  7   depression        6840 non-null   float64
#  8   alcohol           6840 non-null   float64
#  9   mental_disorder   6840 non-null   float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 845.9+ KB

# %%
from sklearn.preprocessing import LabelEncoder
l=LabelEncoder()
for i in df.columns:
    if df[i].dtype == 'object':
        df[i]=l.fit_transform(df[i])

# %%
X = df.drop('mental_disorder',axis=1)
y = df['mental_disorder']

from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(X, y, test_size=0.2, random_state=2)

# %% [markdown]
# # LINEAR REGRESSION

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
lr = LinearRegression()
lr.fit(xtrain,ytrain)

# model evaluation for training set
ytrain_pred = lr.predict(xtrain)
mse = mean_squared_error(ytrain, ytrain_pred)
rmse = (np.sqrt(mean_squared_error(ytrain, ytrain_pred)))
r2 = r2_score(ytrain, ytrain_pred)

print("The model performance for training set")
print("--------------------------------------")
print('MSE is {}'.format(mse))
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")

# model evaluation for testing set
ytest_pred = lr.predict(xtest)
mse = mean_squared_error(ytest, ytest_pred)
rmse = (np.sqrt(mean_squared_error(ytest, ytest_pred)))
r2 = r2_score(ytest, ytest_pred)

print("The model performance for testing set")
print("--------------------------------------")
print('MSE is {}'.format(mse))
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
# Out:
# The model performance for training set
# --------------------------------------
# MSE is 1.3899593726347028
# RMSE is 1.1789653822885144
# R2 score is 0.7413245789600416
#
#
# The model performance for testing set
# --------------------------------------
# MSE is 1.1357545316965028
# RMSE is 1.0657178480707277
# R2 score is 0.7638974087530466

# %% [markdown]
# # Support Vector Machine

# %%
from sklearn.svm import SVR
svr = SVR(kernel='linear')
svr.fit(xtrain, ytrain)

# model evaluation for training set
ytrain_pred = svr.predict(xtrain)
mse = mean_squared_error(ytrain, ytrain_pred)
rmse = (np.sqrt(mean_squared_error(ytrain, ytrain_pred)))
r2 = r2_score(ytrain, ytrain_pred)

print("The model performance for training set")
print("--------------------------------------")
print('MSE is {}'.format(mse))
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")

# model evaluation for testing set
ytest_pred = svr.predict(xtest)
mse = mean_squared_error(ytest, ytest_pred)
rmse = (np.sqrt(mean_squared_error(ytest, ytest_pred)))
r2 = r2_score(ytest, ytest_pred)

print("The model performance for testing set")
print("--------------------------------------")
print('MSE is {}'.format(mse))
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
# Out:
# The model performance for training set
# --------------------------------------
# MSE is 2.1744388569568547
# RMSE is 1.4745978627940755
# R2 score is 0.5953306996428414
#
#
# The model performance for testing set
# --------------------------------------
# MSE is 1.8783955487748165
# RMSE is 1.3705457120340119
# R2 score is 0.6095159261306051

# %% [markdown]
# # RANDOM FOREST REGRESSOR

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
rf.fit(xtrain, ytrain)

# model evaluation for training set
ytrain_pred = rf.predict(xtrain)
mse = mean_squared_error(ytrain, ytrain_pred)
rmse = (np.sqrt(mean_squared_error(ytrain, ytrain_pred)))
r2 = r2_score(ytrain, ytrain_pred)

print("The model performance for training set")
print("--------------------------------------")
print('MSE is {}'.format(mse))
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")

# model evaluation for testing set
ytest_pred = rf.predict(xtest)
mse = mean_squared_error(ytest, ytest_pred)
rmse = (np.sqrt(mean_squared_error(ytest, ytest_pred)))
r2 = r2_score(ytest, ytest_pred)

print("The model performance for testing set")
print("--------------------------------------")
print('MSE is {}'.format(mse))
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
# Out:
# The model performance for training set
# --------------------------------------
# MSE is 0.005270557684684569
# RMSE is 0.07259860663046205
# R2 score is 0.9990191341164045
#
#
# The model performance for testing set
# --------------------------------------
# MSE is 0.030568399833294055
# RMSE is 0.17483821044981573
# R2 score is 0.9936453888498837

# %% [markdown]
# ## RANDOM FOREST PERFORMS WELL ON BOTH TRAINING AND TESTING DATA
